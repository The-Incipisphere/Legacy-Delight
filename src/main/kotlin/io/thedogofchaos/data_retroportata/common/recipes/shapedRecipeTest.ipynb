// %%
import io.thedogofchaos.data_retroportata.MOD_ID
import io.thedogofchaos.data_retroportata.common.recipes.IInputComponent
import io.thedogofchaos.data_retroportata.common.recipes.IOutputComponent
import io.thedogofchaos.data_retroportata.common.recipes.impl.ShapedCraftingRecipe
import io.thedogofchaos.data_retroportata.common.util.SaneResLoc

data class DummyComp(val string: String) : IInputComponent, IOutputComponent {
    override val type = SaneResLoc(MOD_ID, "dummy")
}

// %%
ShapedCraftingRecipe.dissolvePattern(
    listOf(
        " d ",
        " d ",
        " s "
    ),
    mapOf(
        Pair('d', DummyComp("diamond")),
        Pair('s', DummyComp("stick"))
    )
)
// Out:
// [Empty, Filled(component=DummyComp(string=diamond)), Empty, Empty, Filled(component=DummyComp(string=diamond)), Empty, Empty, Filled(component=DummyComp(string=stick)), Empty]

// %%
ShapedCraftingRecipe.dissolvePattern(
    listOf(
        " d",
        "ss"
    ),
    mapOf(
        Pair('d', DummyComp("diamond")),
        Pair('s', DummyComp("stick"))
    )
)
// Out:
// [Empty, Filled(component=DummyComp(string=diamond)), Filled(component=DummyComp(string=stick)), Filled(component=DummyComp(string=stick))]

// %%
ShapedCraftingRecipe.dissolvePattern(
    listOf(
        " d ",
        " d ",
        " s "
    ),
    mapOf(
        Pair('d', DummyComp("diamond")),
        Pair('s', DummyComp("stick")),
        Pair('h', DummyComp("hehe"))
    )
)
// Out:
// java.lang.IllegalStateException: Legend defines symbols that aren't used anywhere in the pattern: [h]
// 	at io.thedogofchaos.data_retroportata.common.recipes.impl.ShapedCraftingRecipe$Companion.dissolvePattern(ShapedCraftingRecipe.kt:81)
// 	at Line_7_jupyter.<init>(Line_7.jupyter.kts:1) at Cell In[5], line 1
// 	at java.base/jdk.internal.reflect.DirectConstructorHandleAccessor.newInstance(DirectConstructorHandleAccessor.java:62)
// 	at java.base/java.lang.reflect.Constructor.newInstanceWithCaller(Constructor.java:499)
// 	at java.base/java.lang.reflect.Constructor.newInstance(Constructor.java:483)
// 	at kotlin.script.experimental.jvm.BasicJvmScriptEvaluator.evalWithConfigAndOtherScriptsResults(BasicJvmScriptEvaluator.kt:122)
// 	at kotlin.script.experimental.jvm.BasicJvmScriptEvaluator.invoke$suspendImpl(BasicJvmScriptEvaluator.kt:48)
// 	at kotlin.script.experimental.jvm.BasicJvmScriptEvaluator.invoke(BasicJvmScriptEvaluator.kt)
// ...

// %%
ShapedCraftingRecipe.dissolvePattern(
    listOf(
        " d ",
        "hdh",
        " s "
    ),
    mapOf(
        Pair('d', DummyComp("diamond")),
        Pair('s', DummyComp("stick"))
    )
)
// Out:
// java.lang.IllegalStateException: Pattern references symbol 'h', but that symbol is not defined in the legend.
// 	at io.thedogofchaos.data_retroportata.common.recipes.impl.ShapedCraftingRecipe$Companion.dissolvePattern(ShapedCraftingRecipe.kt:75)
// 	at Line_8_jupyter.<init>(Line_8.jupyter.kts:1) at Cell In[6], line 1
// 	at java.base/jdk.internal.reflect.DirectConstructorHandleAccessor.newInstance(DirectConstructorHandleAccessor.java:62)
// 	at java.base/java.lang.reflect.Constructor.newInstanceWithCaller(Constructor.java:499)
// 	at java.base/java.lang.reflect.Constructor.newInstance(Constructor.java:483)
// 	at kotlin.script.experimental.jvm.BasicJvmScriptEvaluator.evalWithConfigAndOtherScriptsResults(BasicJvmScriptEvaluator.kt:122)
// 	at kotlin.script.experimental.jvm.BasicJvmScriptEvaluator.invoke$suspendImpl(BasicJvmScriptEvaluator.kt:48)
// 	at kotlin.script.experimental.jvm.BasicJvmScriptEvaluator.invoke(BasicJvmScriptEvaluator.kt)
// ...

// %%
import io.thedogofchaos.data_retroportata.Option

val some: Option<Int> = Option.some(1)
val none: Option<Int> = Option.none()
val shouldntWork = Option.some(null)
println(some)
println(none)
// Out:
// Some(value=1)
// None
